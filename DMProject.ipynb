# %%
# %pwd
# Out:
# 'C:\\Users\\schne'

# %%
# You guys should change your directories to work on the code
# %cd C:\Users\schne\OneDrive\Desktop\data mining\Data Mining project
# Out:
# C:\Users\schne\OneDrive\Desktop\data mining\Data Mining project

# %%
# Making sure that I'm in the right folder
# %pwd
# Out:
# 'C:\\Users\\schne\\OneDrive\\Desktop\\data mining\\Data Mining project'

# %%
# Imprting everything we need for the project to work
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from statistics import mean, median, mode, stdev

# %%
# Weather Dataframe
weather = pd.read_csv("weather.csv")
weather
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
# Each unique station code in the USA
code_df = weather['Station.Code']
code_df
# Out:
# 0        BHM
# 1        HSV
# 2        MOB
# 3        MGM
# 4        ANC
#         ...
# 16738    CPR
# 16739    CYS
# 16740    LND
# 16741    RWL
# 16742    SHR
# Name: Station.Code, Length: 16743, dtype: object

# %%
# Avg temperature accross the data
temp_df = weather['Data.Temperature.Avg Temp']
mean_temp = temp_df.mean()
print("Mean for temp: ", mean_temp)
# Out:
# Mean for temp:  56.08911186764618
